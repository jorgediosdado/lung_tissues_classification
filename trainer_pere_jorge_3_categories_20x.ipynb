# %%
import os
import os
import random
import imageio
import glob
import datetime
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from PIL import Image
from datetime import datetime

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50, EfficientNetB0
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Rescaling
from tensorflow.keras.utils import Sequence, to_categorical
from tensorflow.keras.layers.experimental import preprocessing
from sklearn.utils import class_weight
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tqdm.keras import TqdmCallback
import tensorflow_addons as tfa

from keras import layers
from keras import models
from keras.models import Model


from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, accuracy_score
# Out:
# c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# Function to get paths from private directory
def get_files(base_dir, ext=None):
    assert type(ext) in [list, str]
    ext = [ext] if type(ext) != list else ext
    ret_files = []

    for root, dirs, files in os.walk(base_dir):
        for f in files:
            file_path = os.path.join(root, f)
            # Check if it's a file, not a hidden file, and has the specified extension
            if os.path.isfile(file_path) and not os.path.basename(file_path).startswith('.') and (ext is not None) and any([file_path.endswith(e) for e in ext]) and '20x' in file_path:
                # Check if subfolder names contain specific strings
                if "aca" in file_path:
                    label = 0
                elif "nor" in file_path:
                    label = 1
                elif "scc" in file_path:
                    label = 2
                else:
                    continue

                ret_files.append((file_path, label))

    return ret_files

# %%
# Get paths and labels from private dataset
root_directory = "data\\dataset_2_final\\"

image_paths_and_labels = get_files(root_directory, ['jpg', 'jpeg'])

# Extract image paths and labels
image_paths, labels = zip(*image_paths_and_labels) if image_paths_and_labels else ([], [])

# Print only selected files
print("\nSelected files:")
for path, label in image_paths_and_labels:
    print(path, label)

class_names = sorted(set(labels))
class2int = dict(zip(class_names, range(len(class_names))))
num_classes = len(class_names)

# Convert labels to integers
int_labels = [class2int[label] for label in labels]

print(np.unique(int_labels, return_counts=True))
# Print number of images found
print("Number of images found: ", len(image_paths))
# Out:
# Selected files:
# data\dataset_2_final\aca_bd\aca_bd_20x_0.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_1.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_10.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_12.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_13.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_14.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_15 (2).jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_15.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_16.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_17.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_18.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_2.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_20.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_21.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_22.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_23.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_24.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_25.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_26.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_27.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_28.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_29.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_3.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_30.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_31.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_32.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_33.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_34.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_35.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_37.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_38.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_39.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_4.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_40.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_42.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_5.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_56.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_57.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_6.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_60.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_61.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_62.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_7.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_8.jpg 0
# data\dataset_2_final\aca_bd\aca_bd_20x_9.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_1.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_10.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_11.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_12.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_124.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_13.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_14.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_15.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_16.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_17.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_18.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_19.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_2.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_20.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_3.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_4.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_41.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_5.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_6.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_7.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_70.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_71.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_72.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_73.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_74.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_75.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_76.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_77.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_78.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_79.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_8.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_80.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_81.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_82.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_83.jpg 0
# data\dataset_2_final\aca_md\aca_md_20x_9.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_1.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_10.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_11.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_12.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_13.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_14.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_15.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_16.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_2.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_20.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_3.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_30.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_31.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_32.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_33.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_34.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_35.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_36.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_37.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_38.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_39.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_40.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_43.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_5.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_50.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_51.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_52.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_53.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_54.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_6.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_7.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_8.jpg 0
# data\dataset_2_final\aca_pd\aca_pd_20x_9.jpg 0
# data\dataset_2_final\nor\nor_20x_1.jpg 1
# data\dataset_2_final\nor\nor_20x_10.jpg 1
# data\dataset_2_final\nor\nor_20x_11.jpg 1
# data\dataset_2_final\nor\nor_20x_12.jpg 1
# data\dataset_2_final\nor\nor_20x_13.jpg 1
# data\dataset_2_final\nor\nor_20x_14.jpg 1
# data\dataset_2_final\nor\nor_20x_15.jpg 1
# data\dataset_2_final\nor\nor_20x_16.jpg 1
# data\dataset_2_final\nor\nor_20x_67.jpg 1
# data\dataset_2_final\nor\nor_20x_68.jpg 1
# data\dataset_2_final\nor\nor_20x_69.jpg 1
# data\dataset_2_final\nor\nor_20x_7.jpg 1
# data\dataset_2_final\nor\nor_20x_70.jpg 1
# data\dataset_2_final\nor\nor_20x_71.jpg 1
# data\dataset_2_final\nor\nor_20x_72.jpg 1
# data\dataset_2_final\nor\nor_20x_8.jpg 1
# data\dataset_2_final\nor\nor_20x_9.jpg 1
# data\dataset_2_final\scc_bd\scc_bd_20x_300.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_34.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_35.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_36.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_37.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_38.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_39.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_40.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_41.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_42.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_43.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_44.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_45.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_46.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_47.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_48.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_49.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_50.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_62.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_63.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_64.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_65.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_66.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_67.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_68.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_69.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_70.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_71.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_72.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_80.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_81.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_82.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_83.jpg 2
# data\dataset_2_final\scc_bd\scc_bd_20x_84.jpg 2
# data\dataset_2_final\scc_md\scc_bd_20x_201.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_1.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_11.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_12.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_13.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_14.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_15.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_16.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_17.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_18.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_19.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_2.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_20.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_22.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_23.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_24.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_25.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_26.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_28.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_29.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_3.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_30.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_4.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_5.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_51.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_52.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_53.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_54.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_6.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_60.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_61.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_62.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_7.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_8.jpg 2
# data\dataset_2_final\scc_md\scc_md_20x_9.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_1.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_10.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_11.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_12.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_13.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_14.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_15.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_16.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_17.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_18.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_2.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_200.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_21.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_27.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_3.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_31.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_32.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_33.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_4.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_5.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_50.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_51.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_52.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_53.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_54.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_55.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_56.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_57.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_58.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_59.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_6.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_60.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_61.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_7.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_8.jpg 2
# data\dataset_2_final\scc_pd\scc_pd_20x_9.jpg 2
# (array([0, 1, 2]), array([114,  72, 105], dtype=int64))
# Number of images found:  291

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size=8, image_size=255, shuffle_epoch=True):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle_epoch = shuffle_epoch
        
    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))
    
    def __getitem__(self, idx):
        
        if (idx == 0) and (self.shuffle_epoch):            
            # Shuffle at first batch
            c = list(zip(self.images, self.labels))
            random.shuffle(c)
            self.images, self.labels = zip(*c)
            self.images, self.labels = np.array(self.images), np.array(self.labels)       
        
        images = self.images[idx * self.batch_size : (idx+1) * self.batch_size]
        labels = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]
        
        # Read images
        images = np.array([imageio.v2.imread(im) for im in images])
        
        # Choose one of the four quadrants
        x, y = np.random.choice([0,1], size=2)
        images = images[:,(x*600):(x*600 + 600), (y*800):(y*800 + 800)]
        
        #Todos los modelos tienen capa de rescaling por lo que no es necesaria aqui
        # images = images/255
        
        images = np.array([self.random_crop(im) for im in images])
        labels = to_categorical(labels, num_classes=num_classes)
        
        return images, labels
    
    def random_crop(self, image):
        cropped_image = tf.image.random_crop(image, size=[self.image_size, self.image_size, 3]).numpy()
        return cropped_image

# %%
#Split in training and validation
train_paths, val_paths, train_labels, val_labels = train_test_split(image_paths, labels, test_size=0.15, random_state=42)


#Build the generators
train_generator = CustomDataGenerator(train_paths, train_labels)
val_generator = CustomDataGenerator(val_paths, val_labels, shuffle_epoch=False)

# %%
fig, axs = plt.subplots(2,4, figsize=(25,5))
axs = axs.flatten()

for i in range(8):
    gen = train_generator if i<4 else val_generator
    axs[i].imshow(gen[1][0][i%10])
    axs[i].axis('off')
plt.tight_layout()
plt.show()

# %%
labels = np.concatenate([l.argmax(1) for _, l in tqdm(gen, leave=False)])
class_weights = class_weight.compute_class_weight('balanced',
                                                     classes=np.unique(labels),
                                                     y=list(labels))
class_weights = dict(enumerate(class_weights))
class_weights
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# {0: 0.8148148148148148, 1: 1.3333333333333333, 2: 0.9777777777777777}

# %%
#function to plot the metrics of the trainign and validation

def plot_metrics(history):
    # Plotting training accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['metrics/accuracy'], label='Train')
    plt.plot(history.history['val_metrics/accuracy'], label='Validation')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plotting training loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
def test_model(model):

    test_directory = "data\\validation_final_septiembre\\"


    image_paths_and_labels = get_files(root_directory, ['jpg', 'jpeg'])

    # Extract image paths and labels
    test_image_paths, test_labels = zip(*image_paths_and_labels) if image_paths_and_labels else ([], [])


    test_generator = CustomDataGenerator(test_image_paths, test_labels, shuffle_epoch=False)
    test_predictions = model.predict(test_generator)

    # Convert predictions to class labels
    predicted_labels = np.argmax(test_predictions, axis=1)

    # Calculate metrics
    accuracy = accuracy_score(test_labels, predicted_labels)
    precision = precision_score(test_labels, predicted_labels, average='macro')
    recall = recall_score(test_labels, predicted_labels, average='macro')

    print("Test Accuracy:", accuracy)
    print("Test Precision:", precision)
    print("Test Recall:", recall)



    # Obtain the confusion matrix
    conf_matrix = confusion_matrix(test_labels, predicted_labels)

    # Ensure that labels are unique and match the confusion matrix
    labels = np.unique(np.concatenate((test_labels, predicted_labels)))

    # Visualize the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=labels)
    disp.plot()

# %% [markdown]
# # EFFICIENTNET

# %%
base_model = EfficientNetB0(include_top = False ,weights='imagenet', pooling='avg')

# Introduce a layer of data augmentation
data_augmentation = Sequential([
    preprocessing.RandomRotation(0.2),
    preprocessing.RandomFlip("horizontal"),
    preprocessing.RandomFlip("vertical"),
    preprocessing.RandomZoom(0.2),
    preprocessing.RandomContrast(0.2),
    preprocessing.RandomTranslation(0.2, 0.2),
    preprocessing.RandomHeight(0.2),
    preprocessing.RandomWidth(0.2),    
    preprocessing.RandomContrast(0.2),

])



# # Freeze all layers in the base model
# for layer in base_model.layers:
#     layer.trainable = False
# # Unfreeze the last 10 layers in the base model for fine-tuning
# for layer in base_model.layers[-5:]:
#     layer.trainable = True

#capa de entradas. 
entradas = layers.Input((255, 255, 3))

# Capa de augmentation
x = data_augmentation(entradas)
# Pass the augmented images through the base model
x = base_model(x)
# Add a dense layer
x = layers.Dense(512, activation='relu')(x)
# Add another dense layer
salidas = layers.Dense(num_classes, activation='softmax')(x)
model1 = Model(inputs = entradas, outputs = salidas)
model1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 255, 255, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, None, None, 3)     0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, 1280)              4049571
# _________________________________________________________________
# dense (Dense)                (None, 512)               655872
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 4,706,982
# Trainable params: 4,664,959
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
import datetime

# %%
MODEL_NAME = 'Ef0_20x'
RUN_NAME = ''
log_dir = f'logs/{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}/{MODEL_NAME}{RUN_NAME}'

# %%
#clear cache
tf.keras.backend.clear_session()

# %%
num_epochs = 140
patience = 50
patience_lr = 5

model1.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss='categorical_crossentropy', 
              metrics=[
                    tf.keras.metrics.CategoricalAccuracy(name=f'metrics/accuracy'),
                    tf.keras.metrics.TopKCategoricalAccuracy(3, name=f'metrics/top-3-accuracy'),
                    tfa.metrics.F1Score(num_classes=num_classes, average='macro', name='metrics/F1-macro'),
                    tf.keras.metrics.AUC(multi_label=True, num_labels=num_classes, name='metrics/AUC'),
                    tf.keras.metrics.Precision(name='metrics/precision'),
                    tf.keras.metrics.Recall(name='metrics/recall'),
                    tf.keras.metrics.PrecisionAtRecall(0.99, name='metrics/P@R_99'),
                    tf.keras.metrics.PrecisionAtRecall(0.95, name='metrics/P@R_95'),
                    tf.keras.metrics.PrecisionAtRecall(0.9, name='metrics/P@R_90'),
                    tfa.metrics.MatthewsCorrelationCoefficient(num_classes=num_classes, name='metrics/MCC')
                ],
             )

callbacks =[
       EarlyStopping(monitor='val_loss', restore_best_weights=True, patience=patience),
       ReduceLROnPlateau(monitor='val_loss', patience=patience_lr, min_lr=1e-7),       
       ModelCheckpoint(log_dir, monitor=f"val_loss", save_best_only=True, save_weights_only=True),
       TqdmCallback(),
       TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch=0)

]
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]

# %%
# Train the model using the custom data generators and the debugging callback
history = model1.fit(train_generator, epochs=num_epochs, verbose=1, callbacks=callbacks, validation_data=val_generator,class_weight=class_weights)
# Out:
# c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 1/140
# 31/31 [==============================] - 92s 2s/step - loss: 1.0552 - metrics/accuracy: 0.5425 - metrics/top-3-accuracy: 1.0000 - metrics/F1-macro: 0.5428 - metrics/AUC: 0.7235 - metrics/precision: 0.5707 - metrics/recall: 0.4413 - metrics/P@R_99: 0.3514 - metrics/P@R_95: 0.3643 - metrics/P@R_90: 0.3947 - metrics/MCC: 0.3222 - val_loss: 1.6430 - val_metrics/accuracy: 0.4091 - val_metrics/top-3-accuracy: 1.0000 - val_metrics/F1-macro: 0.2862 - val_metrics/AUC: 0.7197 - val_metrics/precision: 0.4286 - val_metrics/recall: 0.4091 - val_metrics/P@R_99: 0.3548 - val_metrics/P@R_95: 0.3548 - val_metrics/P@R_90: 0.4059 - val_metrics/MCC: 0.1371
# Epoch 2/140
# 31/31 [==============================] - 54s 2s/step - loss: 0.7337 - metrics/accuracy: 0.6599 - metrics/top-3-accuracy: 1.0000 - metrics/F1-macro: 0.6632 - metrics/AUC: 0.8383 - metrics/precision: 0.6754 - metrics/recall: 0.6235 - metrics/P@R_99: 0.3798 - metrics/P@R_95: 0.4886 - metrics/P@R_90: 0.5149 - metrics/MCC: 0.4830 - val_loss: 4.3199 - val_metrics/accuracy: 0.3409 - val_metrics/top-3-accuracy: 1.0000 - val_metrics/F1-macro: 0.1695 - val_metrics/AUC: 0.5842 - val_metrics/precision: 0.3409 - val_metrics/recall: 0.3409 - val_metrics/P@R_99: 0.3333 - val_metrics/P@R_95: 0.3333 - val_metrics/P@R_90: 0.3333 - val_metrics/MCC: 0.0000e+00
# Epoch 3/140
# 31/31 [==============================] - 45s 1s/step - loss: 0.8206 - metrics/accuracy: 0.6356 - metrics/top-3-accuracy: 1.0000 - metrics/F1-macro: 0.6231 - metrics/AUC: 0.8090 - metrics/precision: 0.6504 - metrics/recall: 0.5951 - metrics/P@R_99: 0.3333 - metrics/P@R_95: 0.4328 - metrics/P@R_90: 0.4978 - metrics/MCC: 0.4551 - val_loss: 1.9142 - val_metrics/accuracy: 0.3864 - val_metrics/top-3-accuracy: 1.0000 - val_metrics/F1-macro: 0.2594 - val_metrics/AUC: 0.7172 - val_metrics/precision: 0.3864 - val_metrics/recall: 0.3864 - val_metrics/P@R_99: 0.3333 - val_metrics/P@R_95: 0.3333 - val_metrics/P@R_90: 0.4301 - val_metrics/MCC: 0.0921
# Epoch 4/140
# 31/31 [==============================] - 40s 1s/step - loss: 0.7761 - metrics/accuracy: 0.6478 - metrics/top-3-accuracy: 1.0000 - metrics/F1-macro: 0
- metrics/top-3-accuracy: 1.0000 - metrics/F1-macro: 0.7877 - metrics/AUC: 0.9329 - metrics/precision: 0.7975 - metrics/recall: 0.7652 - metrics/P@R_99: 0.4880 - metrics/P@R_95: 0.6283 - metrics/P@R_90: 0.7079 - metrics/MCC: 0.6763 - val_loss: 0.5145 - val_metrics/accuracy: 0.7500 - val_metrics/top-3-accuracy: 1.0000 - val_metrics/F1-macro: 0.7564 - val_metrics/AUC: 0.9557 - val_metrics/precision: 0.7674 - val_metrics/recall: 0.7500 - val_metrics/P@R_99: 0.5789 - val_metrics/P@R_95: 0.5789 - val_metrics/P@R_90: 0.6250 - val_metrics/MCC: 0.6550
# Epoch 29/140
#  4/31 [==>...........................] - ETA: 21s - loss: 0.2543 - metrics/accuracy: 0.8750 - metrics/top-3-accuracy: 1.0000 - metrics/F1-macro: 0.8788 - metrics/AUC: 0.9832 - metrics/precision: 0.9032 - metrics/recall: 0.8750 - metrics/P@R_99: 0.8000 - metrics/P@R_95: 0.8378 - metrics/P@R_90: 0.8824 - metrics/MCC: 0.8176
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# c:\Users\diosdadj\OneDrive - HP Inc\Master\Lung Cancer Project\lung_tissues_classification\trainer_pere_jorge_3_categories_20x.ipynb Cell 16 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/diosdadj/OneDrive%20-%20HP%20Inc/Master/Lung%20Cancer%20Project/lung_tissues_classification/trainer_pere_jorge_3_categories_20x.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> # Train the model using the custom data generators and the debugging callback
# ----> <a href='vscode-notebook-cell:/c%3A/Users/diosdadj/OneDrive%20-%20HP%20Inc/Master/Lung%20Cancer%20Project/lung_tissues_classification/trainer_pere_jorge_3_categories_20x.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> history = model1.fit(train_generator, epochs=num_epochs, verbose=1, callbacks=callbacks, validation_data=val_generator,class_weight=class_weights)
#
# File c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\keras\engine\training.py:1184, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1177 with tf.profiler.experimental.Trace(
#    1178     'train',
#    1179     epoch_num=epoch,
#    1180     step_num=step,
#    1181     batch_size=batch_size,
#    1182     _r=1):
#    1183   callbacks.on_train_batch_begin(step)
# -> 1184   tmp_logs = self.train_function(iterator)
#    1185   if data_handler.should_sync:
#    1186     context.async_wait()
#
# File c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\eager\def_function.py:885, in Function.__call__(self, *args, **kwds)
#     882 compiler = "xla" if self._jit_compile else "nonXla"
#     884 with OptionalXlaContext(self._jit_compile):
# --> 885   result = self._call(*args, **kwds)
#     887 new_tracing_count = self.experimental_get_tracing_count()
#     888 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\eager\def_function.py:917, in Function._call(self, *args, **kwds)
#     914   self._lock.release()
#     915   # In this case we have created variables on the first call, so we run the
#     916   # defunned version which is guaranteed to never create variables.
# --> 917   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918 elif self._stateful_fn is not None:
#     919   # Release the lock early so that multiple threads can perform the call
#     920   # in parallel.
#     921   self._lock.release()
#
# File c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\eager\function.py:3039, in Function.__call__(self, *args, **kwargs)
#    3036 with self._lock:
#    3037   (graph_function,
#    3038    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039 return graph_function._call_flat(
#    3040     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\eager\function.py:1963, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1959 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1960 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1961     and executing_eagerly):
#    1962   # No tape is watching; skip to running the function.
# -> 1963   return self._build_call_outputs(self._inference_function.call(
#    1964       ctx, args, cancellation_manager=cancellation_manager))
#    1965 forward_backward = self._select_forward_and_backward_functions(
#    1966     args,
#    1967     possible_gradient_type,
#    1968     executing_eagerly)
#    1969 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\eager\function.py:591, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     589 with _InterpolateFunctionError(self):
#     590   if cancellation_manager is None:
# --> 591     outputs = execute.execute(
#     592         str(self.signature.name),
#     593         num_outputs=self._num_outputs,
#     594         inputs=args,
#     595         attrs=attrs,
#     596         ctx=ctx)
#     597   else:
#     598     outputs = execute.execute_with_cancellation(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#    (...)
#     603         ctx=ctx,
#     604         cancellation_manager=cancellation_manager)
#
# File c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\eager\execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted:  MemoryError: Unable to allocate 43.9 MiB for an array with shape (8, 1200, 1600, 3) and data type uint8
# Traceback (most recent call last):
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\ops\script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 645, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 892, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\keras\engine\data_adapter.py", line 822, in wrapped_generator
#     for data in generator_fn():
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\keras\engine\data_adapter.py", line 948, in generator_fn
#     yield x[i]
#
#   File "C:\Users\diosdadj\AppData\Local\Temp\ipykernel_34672\1492217254.py", line 25, in __getitem__
#     images = np.array([imageio.v2.imread(im) for im in images])
#
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 43.9 MiB for an array with shape (8, 1200, 1600, 3) and data type uint8
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) Resource exhausted:  MemoryError: Unable to allocate 43.9 MiB for an array with shape (8, 1200, 1600, 3) and data type uint8
# Traceback (most recent call last):
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\ops\script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 645, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 892, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\keras\engine\data_adapter.py", line 822, in wrapped_generator
#     for data in generator_fn():
#
#   File "c:\Users\diosdadj\Anaconda3\envs\ml\lib\site-packages\keras\engine\data_adapter.py", line 948, in generator_fn
#     yield x[i]
#
#   File "C:\Users\diosdadj\AppData\Local\Temp\ipykernel_34672\1492217254.py", line 25, in __getitem__
#     images = np.array([imageio.v2.imread(im) for im in images])
#
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 43.9 MiB for an array with shape (8, 1200, 1600, 3) and data type uint8
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[confusion_matrix/assert_non_negative_1/assert_less_equal/Assert/AssertGuard/else/_130/confusion_matrix/assert_non_negative_1/assert_less_equal/Assert/AssertGuard/Assert/data_2/_478]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_24584]
#
# Function call stack:
# train_function -> train_function

# %%
#Plot metrics
plot_metrics(history)

# %% [markdown]
# ### Test

# %%
test_model(model1)
# Out:
# Test Accuracy: 0.8694158075601375
# Test Precision: 0.8676005104655485
# Test Recall: 0.8810150375939849
