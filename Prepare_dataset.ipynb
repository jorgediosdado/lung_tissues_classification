# %% [markdown]
# ## Este script sirve para cortar imágenes en n partes y contabilizarlas

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import load_img

import os

import seaborn as sns
from matplotlib import pyplot as plt

from fnmatch import fnmatch

# %%
# Funcion para cortar en trozos

def crop_directory_subdirectory(path, n_horizontal, n_vertical):

    #This function takes a "root" directory and crops all the images in all the subdirectories, crops it in n_pieces, and then removes the ooriginal image

    for subdir, dirs, files in os.walk(path):
        for file in files:       
            
            f = os.path.join(subdir, file)
            im = tf.keras.utils.load_img(f)
            
            imgwidth, imgheight = im.size
            

            trozos_h = int(imgwidth/n_horizontal)
            trozos_v = int(imgheight/n_vertical)
            
            

            for i in range(n_horizontal):
                for j in range(n_vertical):
                    
                    print(f)

                    # print("i = ", i)
                    # print("j = ", j)
                    #print( trozos_v*j ,trozos_h*i ,trozos_v*j + trozos_v,trozos_h*i+ trozos_h)        
                        
                    trozo = im.crop((trozos_h*j ,trozos_v*i ,trozos_h*j + trozos_h,trozos_v*i+ trozos_v))    
                    

                    trozo.save(f + str(i) + "_" + str(j)+ ".jpg")


            os.remove(f)

# %%
# Create a function to undo the cuts and restore it.

# %%
crop_directory_subdirectory('final',2,2)
# Out:
# final\aca_bd 40x_111.jpg
# final\aca_bd 40x_111.jpg
# final\aca_bd 40x_111.jpg
# final\aca_bd 40x_111.jpg
# final\aca_bd_40x_112.jpg
# final\aca_bd_40x_112.jpg
# final\aca_bd_40x_112.jpg
# final\aca_bd_40x_112.jpg
# final\aca_bd_40x_113.jpg
# final\aca_bd_40x_113.jpg
# final\aca_bd_40x_113.jpg
# final\aca_bd_40x_113.jpg
# final\aca_bd_40x_114.jpg
# final\aca_bd_40x_114.jpg
# final\aca_bd_40x_114.jpg
# final\aca_bd_40x_114.jpg
# final\aca_bd_40x_115.jpg
# final\aca_bd_40x_115.jpg
# final\aca_bd_40x_115.jpg
# final\aca_bd_40x_115.jpg
# final\aca_bd_40x_116.jpg
# final\aca_bd_40x_116.jpg
# final\aca_bd_40x_116.jpg
# final\aca_bd_40x_116.jpg
# final\aca_bd_40x_117.jpg
# final\aca_bd_40x_117.jpg
# final\aca_bd_40x_117.jpg
# final\aca_bd_40x_117.jpg
# final\aca_bd_40x_118.jpg
# final\aca_bd_40x_118.jpg
# final\aca_bd_40x_118.jpg
# final\aca_bd_40x_118.jpg
# final\aca_bd_40x_119.jpg
# final\aca_bd_40x_119.jpg
# final\aca_bd_40x_119.jpg
# final\aca_bd_40x_119.jpg
# final\aca_bd_40x_120.jpg
# ...

# %%
def rename_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for filename in files:
            # Get the full path of the file
            file_path = os.path.join(root, filename)

            # Check if the path represents a file (not a directory)
            if os.path.isfile(file_path):
                # Convert the filename to lowercase
                new_filename = filename.lower()

                # Construct the new path with the renamed file
                new_file_path = os.path.join(root, new_filename)

                # Rename the file
                os.rename(file_path, new_file_path)

# Specify the path to the main folder containing the subfolders and files
folder_path = 'private_dataset'

# Call the function to rename the files
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for filename in files:
            # Get the full path of the file
            file_path = os.path.join(root, filename)

            # Check if the path represents a file (not a directory)
            if os.path.isfile(file_path):
                # Split the filename into base name and extension
                base_name, extension = os.path.splitext(filename)

                # Add underscore before and after '20x' and '40x'
                new_base_name = base_name.replace('__', '_')
                # Construct the new filename
                new_filename = new_base_name + extension

                # Construct the new path with the renamed file
                new_file_path = os.path.join(root, new_filename)

                # Rename the file
                os.rename(file_path, new_file_path)

# Specify the path to the main folder containing the subfolders and files
folder_path = 'new_private_dataset_prefinal'

# Call the function to rename the files
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for filename in files:
            # Get the full path of the file
            file_path = os.path.join(root, filename)

            # Check if the path represents a file (not a directory)
            if os.path.isfile(file_path):
                # Remove spaces from the filename
                new_filename = filename.replace('__', '_')

                # Construct the new path with the renamed file
                new_file_path = os.path.join(root, new_filename)

                # Rename the file
                os.rename(file_path, new_file_path)

# Specify the path to the main folder containing the subfolders and files
folder_path = 'new_private_dataset'
# Call the function to rename the files
rename_files(folder_path)

# %%
folder_path = 'test_set_private'

# %%
# Iterate over the files in the folder
for filename in os.listdir(folder_path):
            
        old_name = os.path.join(folder_path, filename)

              
        parts = filename.split('_')
        
        parte3 = parts[2].split('.')

        # Rearrange the parts to the new format
        new_name = f"{parts[0]}_{parts[1]}_{parte3[0]}_{parts[2]}{'.jpg'}"

       
        new_name = os.path.join(folder_path, new_name)
        print(new_name)
        # Rename the file
        os.rename(old_name, new_name)
# Out:
# test_set_private\aca_100_20X_20X.jpg.jpg
# test_set_private\aca_58_20X_20X.jpg.jpg
# test_set_private\aca_59_20X_20X.jpg.jpg
# test_set_private\aca_60_20X_20X.jpg.jpg
# test_set_private\aca_61_20X_20X.jpg.jpg
# test_set_private\aca_62_20X_20X.jpg.jpg
# test_set_private\aca_77_20X_20X.jpg.jpg
# test_set_private\aca_78_40X_40X.jpg.jpg
# test_set_private\aca_79_20X_20X.jpg.jpg
# test_set_private\aca_80_20X_20X.jpg.jpg
# test_set_private\aca_81_20X_20X.jpg.jpg
# test_set_private\aca_82_20X_20X.jpg.jpg
# test_set_private\aca_83_20X_20X.jpg.jpg
# test_set_private\aca_84_20X_20X.jpg.jpg
# test_set_private\aca_85_20X_20X.jpg.jpg
# test_set_private\aca_86_20X_20X.jpg.jpg
# test_set_private\aca_87_20X_20X.jpg.jpg
# test_set_private\aca_88_20X_20X.jpg.jpg
# test_set_private\aca_89_20X_20X.jpg.jpg
# test_set_private\aca_90_20X_20X.jpg.jpg
# test_set_private\aca_91_20X_20X.jpg.jpg
# test_set_private\aca_92_20X_20X.jpg.jpg
# test_set_private\aca_93_20X_20X.jpg.jpg
# ...

# %%
# Esta celda quita el .jpg del nombre y lo sustituye por _

folder_path = "final_cut"  # Reemplaza con la ruta real de tu carpeta

for filename in os.listdir(folder_path):
    if filename.endswith(".jpg"):
        new_filename = filename.replace(".jpg", "_")
        os.rename(os.path.join(folder_path, filename), os.path.join(folder_path, new_filename + ".jpg"))

# %%
import os
import csv

folder_path = "new_private_dataset"  # Replace with the actual path to your folder
output_csv = "HC.csv"  # Name of the output CSV file

with open(output_csv, "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Filename"])  # Write header row

    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            writer.writerow([filename])
